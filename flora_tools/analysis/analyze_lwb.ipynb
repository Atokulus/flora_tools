# %%
# %load_ext autoreload

# %%
# %autoreload

# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %% [markdown]
# ## LWB Slots

# %%
# %matplotlib notebook

import flora_tools.lwb_math
from flora_tools.lwb_math import LWBMath

plt.figure()

boxes = LWBMath.plot_round(4)
ax = plt.gca()
ax.yaxis.set_visible(False)

for box in boxes:
    ax.add_patch(box)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

import lwb_math
from lwb_math import LWBMath

plt.figure()

boxes = []
boxes.extend(LWBMath.plot_round(9, [
    {'type': 'contention', 'acked': True},
    {'type': 'contention', 'acked': True},
    {'type': 'contention', 'acked': True},
    {'type': 'contention', 'acked': True},
    {'type': 'contention', 'acked': True},
    {'type': 'contention', 'acked': True},
    {'type': 'contention', 'acked': True},
    {'type': 'contention', 'acked': True},

]))

ax = plt.gca()
ax.yaxis.set_visible(False)

for box in boxes:
    ax.add_patch(box)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %autoreload

# %%
from sim.sim_network import SimNetwork

# %%
plt.figure()
network = SimNetwork(count=10, seed=0)
network.draw(modulation=9)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
