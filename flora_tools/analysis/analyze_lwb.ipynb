# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
# Out:
# [autoreload of flora_tools.sim.lwb_schedule_manager failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.7/dist-packages/IPython/extensions/autoreload.py", line 368, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.7/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 722, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 858, in get_code
#   File "<frozen importlib._bootstrap_external>", line 789, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/atok/PycharmProjects/flora_tools/flora_tools/sim/lwb_schedule_manager.py", line 114
#     round_marker =
#                  ^
# SyntaxError: invalid syntax
# ]

# %%
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %% [markdown]
# ## LWB Slots

# %%
# %autoreload

# %%
# %matplotlib notebook

from flora_tools.lwb_visualizer import LWBVisualizer
from flora_tools.lwb_round import LWBRound, LWBDataSlotItem

plt.figure(figsize=[10,10])
ax = plt.gca()
ax.yaxis.set_visible(False)

round = LWBRound.create_sync_round(0, 0)
boxes = LWBVisualizer.plot_round(round, ax)

round = LWBRound.create_notification_round(round.round_end_marker, 3,[
    LWBDataSlotItem(data_payload=8),
]*32)
boxes = LWBVisualizer.plot_round(round, ax, track=1)

round = LWBRound.create_lp_notification_round(round.round_end_marker, 3, 8)
boxes = LWBVisualizer.plot_round(round, ax, track=2)

round = LWBRound.create_stream_request_round(round.round_end_marker, 3, 8)
boxes = LWBVisualizer.plot_round(round, ax, track=0)

round = LWBRound.create_data_round(round.round_end_marker, 3, [
    LWBDataSlotItem(data_payload=255),
]*32)
boxes = LWBVisualizer.plot_round(round, ax, track=1)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %autoreload

# %%
from sim.sim_network import SimNetwork

# %%
plt.figure()
network = SimNetwork(count=10, seed=0)
network.draw(modulation=0)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
